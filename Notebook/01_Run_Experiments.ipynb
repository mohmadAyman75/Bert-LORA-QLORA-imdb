# %% [markdown]
# # Run experiments
#
# Run `Preprocessing.ipynb` first. Then use this notebook to launch compact experiments.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name.lower() == "notebook" else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT))
PROJECT_ROOT

# %% [markdown]
# ## Smoke test
#
# Use a small sample first to confirm the environment works.

# %%
# %cd {PROJECT_ROOT}
# !{sys.executable} -m src.experiments --method feature --epochs 1 --sample-size 200

# %% [markdown]
# ## Main runs
#
# Uncomment the cells you want to run. Full runs may take time on a local GPU.

# %%
# !{sys.executable} -m src.experiments --method feature --epochs 3
# !{sys.executable} -m src.experiments --method lora --epochs 3
# !{sys.executable} -m src.experiments --method qlora --epochs 3

# %%
# Run all, skipping QLoRA if bitsandbytes is not ready on Windows.
# !{sys.executable} -m src.experiments --method all --epochs 3 --seeds 42 --skip-qlora
